# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %%
# Importing the dataset

df = pd.read_csv('datasets/Data Analysis/train.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### Why do EDA
#
# - Model building
# - Analysis and reporting
# - Validate assumptions
# - Handling missing values
# - feature engineering
# - detecting outliers

# %% [markdown]
# ***Remember it is an iterative process***
#
# **Steps in EDA**
# - First `Categorize` each column.
# - Do `Univariate Analysis`.
# - Then do `Bivariate Analysis`.
# - Then perform `Multivariate Analysis`.
# - Now we can perform `Feature Engineering`
#   - Here we can detect `Outliers`
#   - Also we can impute the `Missing values`
# - Then again we can perform `Univariate`, `Bivariate` and `Multivariate` Analysis.
# - At the end we can write the conclusisons.

# %% [markdown]
# ### Column Types
#
# - **Numerical** - `Age`, `Fare`, `PassengerId`
# - **Categorical** - `Survived`, `Pclass`, `Sex`, `SibSp`, `Parch`, `Embarked`
# - **Mixed** - `Name`, `Ticket`, `Cabin`

# %% [markdown]
# ### Univariate Analysis
#
# Univariate analysis focuses on analyzing each feature in the dataset independently.
#
# - **Distribution analysis**: The distribution of each feature is examined to identify its `shape`, `central tendency`, and `dispersion`.
#
# - **Identifying potential issues**: Univariate analysis helps in identifying potential problems with the data such as `outliers`, `skewness`, and `missing values`.

# %% [markdown]
# #### The shape of a data distribution refers to its overall pattern or form as it is represented on a graph. Some common shapes of data distributions include:
#
# - **Normal Distribution**: A symmetrical and bell-shaped distribution where the mean, median, and mode are equal and the majority of the data falls in the middle of the distribution with gradually decreasing frequencies towards the tails.
#
# - **Skewed Distribution**: A distribution that is not symmetrical, with one tail being longer than the other. It can be either positively skewed (right-skewed) or negatively skewed (left-skewed).
#
# - **Bimodal Distribution**: A distribution with two peaks or modes.
#
# - **Uniform Distribution**: A distribution where all values have an equal chance of occurring.
#
# The shape of the data distribution is important in identifying the presence of `outliers`, `skewness`, and the type of statistical tests and models that can be used for further analysis.

# %% [markdown]
# #### **Dispersion** is a statistical term used to describe the spread or variability of a set of data. It measures how far the values in a data set are spread out from the central tendency (mean, median, or mode) of the data.
#
# There are several measures of dispersion, including:
#
# - **Range**: The difference between the largest and smallest values in a data set.
#
# - **Variance**: The average of the squared deviations of each value from the mean of the data set.
#
# - **Standard Deviation**: The square root of the variance. It provides a measure of the spread of the data that is in the same units as the original data.
#
# - **Interquartile range (IQR)**: The range between the first quartile (25th percentile) and the third quartile (75th percentile) of the data.
#
# Dispersion helps to describe the spread of the data, which can help to identify the presence of outliers and skewness in the data.

# %% [markdown]
# ### Steps of doing Univariate Analysis on Numerical columns
#
# - **Descriptive Statistics**: Compute basic summary statistics for the column, such as `mean`, `median`, `mode`, `standard deviation`, `range`, and `quartiles`. These statistics give a general understanding of the distribution of the data and can help identify skewness or outliers.
#
# - **Visualizations**: Create visualizations to explore the distribution of the data. Some common visualizations for numerical data include `histograms`, `box plots`, and `density plots`. These visualizations provide a visual representation of the distribution of the data and can help identify skewness an outliers.
#
# - **Identifying Outliers**: Identify and examine any outliers in the data. Outliers can be identified using visualizations. It is important to determine whether the outliers are due to `measurement errors`, `data entry errors`, or `legitimate differences` in the data, and to decide whether to include or exclude them from the analysis.
#
# - **Skewness**: Check for skewness in the data and consider transforming the data or using robust statistical methods that are less sensitive to skewness, if necessary.
#
# - **Conclusion**: Summarize the findings of the EDA and make decisions about how to proceed with further analysis.

# %% [markdown]
# ### `Age`

# %%
# Getting statistical details about the column

df['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
# Creating a histogram to see the distribution

df['Age'].plot(kind='hist', bins=20)
plt.show()

# %%
# Doing kde plot to see the distribution

df['Age'].plot(kind='kde')
plt.show()

# %%
# Checking the skewnwss of the column

df['Age'].skew()
# Out:
# 0.38910778230082704

# %%
# Creating a boxplot to find the outliers

df['Age'].plot(kind='box')
plt.show()

# %%
# Checking passengers whose age is more than 65

df[df['Age'] > 65]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 33            34         0       2                 Wheadon, Mr. Edward H
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 672          673         0       2           Mitchell, Mr. Henry Michael
# 745          746         0       1          Crosby, Capt. Edward Gifford
# 851          852         0       3                   Svensson, Mr. Johan
#
#       Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 33   male  66.0      0      0  C.A. 24579  10.5000   NaN        S
# 96   male  71.0      0      0    PC 17754  34.6542    A5        C
# 116  male  70.5      0      0      370369   7.7500   NaN        Q
# ...

# %%
# Checking the percentage of null values in the column

df['Age'].isnull().sum()/len(df['Age'])
# Out:
# 0.19865319865319866

# %%
# Another way to check it

df['Age'].isnull().value_counts(normalize=True)
# Out:
# False    0.801347
# True     0.198653
# Name: Age, dtype: float64

# %% [markdown]
# **Conclusions**
#
# - `Age` is normally(almost) distributed.
# - `20%` of the values are missing.
# - There are some outliers.

# %% [markdown]
# ### `Fare`
#
# - Here performing same steps on this column also.

# %%
df['Fare'].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
df['Fare'].plot(kind='hist')
plt.show()

# %%
df['Fare'].plot(kind='kde')
plt.show()

# %%
df['Fare'].skew()
# Out:
# 4.787316519674893

# %%
df['Fare'].plot(kind='box')
plt.show()

# %%
df[df['Fare'] > 250]
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 27            28         0       1         Fortune, Mr. Charles Alexander
# 88            89         1       1             Fortune, Miss. Mabel Helen
# 258          259         1       1                       Ward, Miss. Anna
# 311          312         1       1             Ryerson, Miss. Emily Borie
# 341          342         1       1         Fortune, Miss. Alice Elizabeth
# 438          439         0       1                      Fortune, Mr. Mark
# 679          680         1       1     Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1                 Lesurer, Mr. Gustave J
# 742          743         1       1  Ryerson, Miss. Susan Parker "Suzette"
#
#         Sex   Age  SibSp  Parch    Ticket      Fare            Cabin Embarked
# 27     male  19.0      3      2     19950  263.0000      C23 C25 C27        S
# ...

# %%
df['Fare'].isnull().sum()
# Out:
# 0

# %% [markdown]
# **Conclusions**
#
# - The data is highly(positively) skewed.
# - `Fare` col actually contains the group fare and not the individual fare(This migth be an issue).
# - We need to create a new col called `individual fare`.

# %% [markdown]
# ### Steps of doing Univariate Analysis on Categorical columns
#
# **Descriptive Statistics**: Compute the frequency distribution of the categories in the column. This will give a general understanding of the distribution of the categories and their relative frequencies.
#
# **Visualizations**: Create visualizations to explore the distribution of the categories. Some common visualizations for categorical data include `count plots` and `pie charts`. These visualizations provide a visual representation of the distribution of the categories and can help identify any patterns or anomalies in the data.
#
# **Missing Values**: Check for missing values in the data and decide how to handle them. Missing values can be imputed or excluded from the analysis, depending on the research question and the data set.
#
# **Conclusion**: Summarize the findings of the EDA and make decisions about how to proceed with further analysis.

# %% [markdown]
# ### `Embarked`

# %%
# Checking frequency of each value of the column

df['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
# Plotting to visualize the result

df['Embarked'].value_counts().plot(kind='bar')
plt.show()

# %%
# Checking through a pie chart

df['Embarked'].value_counts().plot(kind='pie',autopct='%0.1f%%')
plt.show()

# %%
df["Embarked"].isnull().sum()
# Out:
# 2

# %% [markdown]
# **Conclusions**
#
# - There are two missing values in the column.

# %% [markdown]
# ### `Survived`

# %%
df['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
df['Survived'].value_counts().plot(kind='bar')
plt.show()

# %%
df['Survived'].value_counts().plot(kind='pie',autopct='%0.1f%%')
plt.show()

# %%
df['Survived'].isnull().sum()
# Out:
# 0

# %% [markdown]
# **Conclusions**

# %% [markdown]
# ### `Pclass`

# %%
df['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
df['Pclass'].value_counts().plot(kind='bar')
plt.show()

# %%
df['Pclass'].value_counts().plot(kind='pie',autopct='%0.1f%%')
plt.show()

# %%
df['Pclass'].isnull().sum()
# Out:
# 0

# %% [markdown]
# **Conclusions**
#
# - Surprisingly less people travelled in `Pclass 2` and more people travelled in `Pclass 1`.

# %% [markdown]
# ### `Sex`

# %%
df['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
df['Sex'].value_counts().plot(kind='bar')
plt.show()

# %%
df['Sex'].value_counts().plot(kind='pie',autopct='%0.1f%%')
plt.show()

# %%
df['Sex'].isnull().sum()
# Out:
# 0

# %% [markdown]
# **Conclusions**

# %% [markdown]
# ### `SibSp`

# %%
df['SibSp'].value_counts()
# Out:
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: SibSp, dtype: int64

# %%
df['SibSp'].value_counts().plot(kind='bar')
plt.show()

# %%
df['SibSp'].value_counts().plot(kind='pie',autopct='%0.1f%%')
plt.show()

# %%
df['SibSp'].isnull().sum()
# Out:
# 0

# %% [markdown]
# **Conclusions**
#
# - Most passengers were travelling alone.

# %% [markdown]
# ### `Parch`

# %%
df['Parch'].value_counts()
# Out:
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: Parch, dtype: int64

# %%
df['Parch'].value_counts().plot(kind='bar')
plt.show()

# %%
df['Parch'].value_counts().plot(kind='pie',autopct='%0.1f%%')
plt.show()

# %%
df['Parch'].isnull().sum()
# Out:
# 0

# %% [markdown]
# **Conclusions**
#
# - Most passengers were travelling alone.
# - `Parch` and `SibSp` cols can be merged to form  a new col called `family_size`.
# - Also we can create a new col called `is_alone` for the passengers travelling alone.

# %% [markdown]
# ### Mixed Columns:
#
# **Conclusions**
# - Need to do Feature Engineering on these columns to get more insights

# %% [markdown]
# ### Steps of doing Bivariate Analysis
#
# - Select 2 cols
# - Understand the type of their relationship.<br><br>
#     1. **Numerical - Numerical**<br>
#         a. You can plot graphs like `scatterplot(regression plots)`, `2D histplot`, `2D KDEplots`<br>
#         b. Check `correlation coefficent` to check linear relationship.<br><br>
#     2. **Numerical - Categorical** <br>
#         a. create visualizations that compare the distribution of the numerical data across different categories of the categorical data.<br>
#         b. You can plot graphs like `barplot`, `boxplot`, `kdeplot`, `violinplot` and even `scatterplots`<br><br>
#     3. **Categorical - Categorical**<br>
#         a. You can create cross-tabulations or contingency tables that show the distribution of values in one categorical column, grouped by the values in the other categorical column.<br>
#         b. You can plots like `heatmap`, `stacked barplots`, `treemaps`.<br><br>
#
# - Write your conclusions

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# - Here the most important column is `Survived` and `Age`.
# - As `Age` has some missing values so we can find how it is distributed with other columns.
# - So now we can do `Bivariate Analysis` with all other columns.

# %% [markdown]
# **Comparing `survived` with others**

# %% [markdown]
# ### `Survived` vs `Pclass`

# %%
# Categorical vs Categorical
# So we need to create a Contingency table also known as Crosstab
# So here we want to see for each Pclass how many survived?

pd.crosstab(df['Survived'], df['Pclass'])
# Out:
# Pclass      1   2    3
# Survived
# 0          80  97  372
# 1         136  87  119

# %%
# So here we want to see for each Pclass what is the percentage of survival?
# To do this we need to add a parameter "normalize" 
# Here we want to normalize on the basis of "columns"
# And multiplying with 100 to get values in full number

pd.crosstab(df['Survived'], df['Pclass'], normalize='columns')*100
# Out:
# Pclass            1          2          3
# Survived
# 0         37.037037  52.717391  75.763747
# 1         62.962963  47.282609  24.236253

# %%
# Now visualizing the result using heatmap

sns.heatmap(pd.crosstab(df['Survived'], df['Pclass'], normalize='columns')*100)
plt.show()

# %% [markdown]
# **Conclusions**
#
# - Clearly chances of survival was best in `Pclass 1` and worst in `Pclass 3`.

# %% [markdown]
# ### `Survived` vs `Sex`

# %%
pd.crosstab(df['Survived'], df['Sex'], normalize='columns')*100
# Out:
# Sex          female       male
# Survived
# 0         25.796178  81.109185
# 1         74.203822  18.890815

# %% [markdown]
# **Conclusions**
#
# - Chances of female for surviving was better than male.

# %% [markdown]
# ### `Survived` vs `Embarked`

# %%
pd.crosstab(df['Survived'], df['Embarked'], normalize='columns')*100
# Out:
# Embarked          C          Q          S
# Survived
# 0         44.642857  61.038961  66.304348
# 1         55.357143  38.961039  33.695652

# %% [markdown]
# **Conclusions**
#
# - Here also it seems there is a relation between the boarding station.
# - We can see that `55%` passengers survived who board from Ciborg instead of Queensland with `38%` and Southampton with `33%` chances of survival.
# - So we can assume that most of the passengers who board from Ciborg are either Female or they are travelling in `Pclass 1` as we can see from other results that chances of survivng increase with these 2 conditions.

# %% [markdown]
# ### `Sex` vs `Embarked`
# #### and
# ### `Sex` vs `Pclass`
#
# - Checking our assumptions

# %%
pd.crosstab(df['Sex'], df['Embarked'], normalize='columns')*100
# Out:
# Embarked          C          Q          S
# Sex
# female    43.452381  46.753247  31.521739
# male      56.547619  53.246753  68.478261

# %%
pd.crosstab(df['Pclass'], df['Embarked'], normalize='columns')*100
# Out:
# Embarked          C          Q          S
# Pclass
# 1         50.595238   2.597403  19.720497
# 2         10.119048   3.896104  25.465839
# 3         39.285714  93.506494  54.813665

# %% [markdown]
# **Conclusions**
#
# - So the higher rate of survival boarded from Ciborg was not due to their gender but because most of the people boarded from Ciborg were travelling in `Pclass 1`.
# - So we can say that most rich people boarded from Ciborg.
# - Also we can say that chances of survival increased with `Pclass 1`.

# %% [markdown]
# ### `Survived` vs `Age`
#
# - Testing the relationship between `Age` and `Survived`
# - We want to see the chances of survival on the basis of age.

# %%
# Here we are doing Numerical (age) vs Categorical (survived)
# Here first we find out the passengers who survived i.e. Survived == 1
# Then taking their "Age" column
# Then making a "kde plot"
# Doing the same for not survived as Survived == 0

df[df['Survived'] == 1]['Age'].plot(kind='kde', label='Survived')
df[df['Survived'] == 0]['Age'].plot(kind='kde', label='Not Survived')

plt.legend()
plt.show()

# %%
# Checking the average age of "Pclass 1"

df[df['Pclass'] == 1]['Age'].mean()
# Out:
# 38.233440860215055

# %% [markdown]
# **Conclusions**
#
# - The passengers in the age group of `0` to `5` i.e. if he/she is a kid he/she has a better chance of surviving.
# - The passengers in the age group of `10` to `40` has a lesser chance of survival.
# - Also if the age group is around `40` they have a better chance of durvival. But this is also due to most of people in this age area were travelling in `Pclass 1`.
# - Now if the age is more than `60` they have less chance of survival.

# %% [markdown]
# **Task**
#
# - On the basis of `Age` we can compare with other columns as we need to predict the missing values in `Age`.
# - So we can find which are the columns on which `Age` is more dependent.

# %% [markdown]
# ### Feature Engineering
#
# - Feature Engineering on `Fare`, `SibSp` and `Parch` columns.
# - There `Fare` column shows the group fare and not individual fare for each individual of the group.
# - So we will try to create a new column contains individual fare.

# %%
# Checking how many passengers were travelling along with siblings or spouse

df['SibSp'].value_counts()
# Out:
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: SibSp, dtype: int64

# %%
# Checking the passengers who were travelling with most companions

df[df['SibSp'] == 8]
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 159          160         0       3         Sage, Master. Thomas Henry    male
# 180          181         0       3       Sage, Miss. Constance Gladys  female
# 201          202         0       3                Sage, Mr. Frederick    male
# 324          325         0       3           Sage, Mr. George John Jr    male
# 792          793         0       3            Sage, Miss. Stella Anna  female
# 846          847         0       3           Sage, Mr. Douglas Bullen    male
# 863          864         0       3  Sage, Miss. Dorothy Edith "Dolly"  female
#
#      Age  SibSp  Parch    Ticket   Fare Cabin Embarked
# 159  NaN      8      2  CA. 2343  69.55   NaN        S
# 180  NaN      8      2  CA. 2343  69.55   NaN        S
# 201  NaN      8      2  CA. 2343  69.55   NaN        S
# 324  NaN      8      2  CA. 2343  69.55   NaN        S
# 792  NaN      8      2  CA. 2343  69.55   NaN        S
# ...

# %% [markdown]
# **Notes:**
#
# - Here we can see all these passengers belong to a family whose surname was `Sage`.
# - Also their `Ticket`, `Fare` and `Embarked` i.e. boarding station was same.

# %%
# Now taking all the family members on the basis of ticket
# Here the problem is instead of getting 11 rows we are getting just 7 rows.
# So either the other 4 have different tickets or the data is missing.

df[df['Ticket'] == 'CA. 2343']
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 159          160         0       3         Sage, Master. Thomas Henry    male
# 180          181         0       3       Sage, Miss. Constance Gladys  female
# 201          202         0       3                Sage, Mr. Frederick    male
# 324          325         0       3           Sage, Mr. George John Jr    male
# 792          793         0       3            Sage, Miss. Stella Anna  female
# 846          847         0       3           Sage, Mr. Douglas Bullen    male
# 863          864         0       3  Sage, Miss. Dorothy Edith "Dolly"  female
#
#      Age  SibSp  Parch    Ticket   Fare Cabin Embarked
# 159  NaN      8      2  CA. 2343  69.55   NaN        S
# 180  NaN      8      2  CA. 2343  69.55   NaN        S
# 201  NaN      8      2  CA. 2343  69.55   NaN        S
# 324  NaN      8      2  CA. 2343  69.55   NaN        S
# 792  NaN      8      2  CA. 2343  69.55   NaN        S
# ...

# %%
# Now checking on the basis of surname

df[df['Name'].str.contains('Sage')]
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 159          160         0       3         Sage, Master. Thomas Henry    male
# 180          181         0       3       Sage, Miss. Constance Gladys  female
# 201          202         0       3                Sage, Mr. Frederick    male
# 324          325         0       3           Sage, Mr. George John Jr    male
# 641          642         1       1               Sagesser, Mlle. Emma  female
# 792          793         0       3            Sage, Miss. Stella Anna  female
# 846          847         0       3           Sage, Mr. Douglas Bullen    male
# 863          864         0       3  Sage, Miss. Dorothy Edith "Dolly"  female
#
#       Age  SibSp  Parch    Ticket   Fare Cabin Embarked
# 159   NaN      8      2  CA. 2343  69.55   NaN        S
# 180   NaN      8      2  CA. 2343  69.55   NaN        S
# 201   NaN      8      2  CA. 2343  69.55   NaN        S
# ...

# %% [markdown]
# - It is due to the dataset is incomplete.
# - So we need to get the `test` dataset.

# %%
# Importing the test dataset
# But it doesnot have the Survived column

df1 = pd.read_csv('datasets/Data Analysis/test.csv')
df1
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
# Doing concatination

df = pd.concat([df, df1])

# %%
# Checking the dataset
# Here the rows from test dataset will have NaN value in Survived column

df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Now checking on the basis of ticket
# Now we can see there are 11 people of that famil;y

df[df['Ticket'] == 'CA. 2343']
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 159          160       0.0       3         Sage, Master. Thomas Henry    male
# 180          181       0.0       3       Sage, Miss. Constance Gladys  female
# 201          202       0.0       3                Sage, Mr. Frederick    male
# 324          325       0.0       3           Sage, Mr. George John Jr    male
# 792          793       0.0       3            Sage, Miss. Stella Anna  female
# 846          847       0.0       3           Sage, Mr. Douglas Bullen    male
# 863          864       0.0       3  Sage, Miss. Dorothy Edith "Dolly"  female
# 188         1080       NaN       3                    Sage, Miss. Ada  female
# 342         1234       NaN       3              Sage, Mr. John George    male
# 360         1252       NaN       3        Sage, Master. William Henry    male
# 365         1257       NaN       3     Sage, Mrs. John (Annie Bullen)  female
#
# ...

# %%
# Now creating a column named "individual_fare"
# The logic is dividing the fare with number of siblings_spouse, number of parent_child and 1
# The "1" is for the passenger itself

df['individual_fare'] = df['Fare']/(df['SibSp'] + df['Parch'] + 1)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Now plotting on the basis of this individual value

df['individual_fare'].plot(kind='box')
plt.show()

# %%
# Checking statistical results of both the columns

df[['individual_fare','Fare']].describe()
# Out:
#        individual_fare         Fare
# count      1308.000000  1308.000000
# mean         20.518215    33.295479
# std          35.774337    51.758668
# min           0.000000     0.000000
# 25%           7.452767     7.895800
# 50%           8.512483    14.454200
# 75%          24.237500    31.275000
# max         512.329200   512.329200

# %% [markdown]
# - It seems there is a passenger who has paid `512`

# %%
# let's see the passenger with "512"

df[df["individual_fare"] == 512.3292]
# Out:
#      PassengerId  Survived  Pclass                    Name     Sex   Age  \
# 258          259       1.0       1        Ward, Miss. Anna  female  35.0
# 737          738       1.0       1  Lesurer, Mr. Gustave J    male  35.0
#
#      SibSp  Parch    Ticket      Fare Cabin Embarked  individual_fare
# 258      0      0  PC 17755  512.3292   NaN        C         512.3292
# 737      0      0  PC 17755  512.3292  B101        C         512.3292

# %% [markdown]
# **Now creating a new column named `family_size` combining of `SibSp` and `Parch` columns**

# %%
# Original dataset

df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['family_size'] = df['SibSp'] + df['Parch'] + 1
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# **Now creating a new column named `family_type` to categorize on the basis of travelling companions**

# %%
# Creating a function to create family_type
# 1 -> alone
# 2-4 -> small
# >5 -> large

def transform_family_size(num):
    if num == 1:
        return 'alone'
    elif num>1 and num <5:
        return "small"
    else:
        return "large"

# %%
# Apllying the function

df['family_type'] = df['family_size'].apply(transform_family_size)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Now doing a crosstab to see chances of survival for passengers on the basis of their number of companions

pd.crosstab(df['Survived'], df['family_type'], normalize='columns')*100
# Out:
# family_type      alone      large      small
# Survived
# 0.0          69.646182  83.870968  42.123288
# 1.0          30.353818  16.129032  57.876712

# %% [markdown]
# **Conclusions**
#
# - So we can see that passengers who were travelling alone has less chance of survival. If travelling with a large family then chance of survival is minimal, but if travelling in a small family there is a better chance of surviving.
# - So this column is very useful.

# %%
# Differentiating the surname from the name so we can identify the families easily

df['surname'] = df['Name'].str.split(',').str.get(0)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Doing same for title

df['title'] = df['Name'].str.split(',').str.get(1).str.strip().str.split(' ').str.get(0)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Checking different values in title

df["title"].value_counts()
# Out:
# Mr.          757
# Miss.        260
# Mrs.         197
# Master.       61
# Rev.           8
# Dr.            8
# Col.           4
# Mlle.          2
# Major.         2
# Ms.            2
# Lady.          1
# Sir.           1
# Mme.           1
# Don.           1
# Capt.          1
# the            1
# Jonkheer.      1
# Dona.          1
# Name: title, dtype: int64

# %%
# Replacing titles 'Dr.','Col.','Major.','Don.','Capt.','the','Jonkheer.' with "other" 

df['title'] = df['title'].str.replace('Rev.','other')
df['title'] = df['title'].str.replace('Dr.','other')
df['title'] = df['title'].str.replace('Col.','other')
df['title'] = df['title'].str.replace('Major.','other')
df['title'] = df['title'].str.replace('Don.','other')
df['title'] = df['title'].str.replace('Capt.','other')
df['title'] = df['title'].str.replace('the','other')
df['title'] = df['title'].str.replace('Jonkheer.','other')

# %%
# Again checking

df["title"].value_counts()
# Out:
# Mr.         757
# Miss.       260
# Mrs.        197
# Master.      61
# ootherr      24
# Ms.           2
# Mlle.         2
# other         2
# Mme.          1
# Lady.         1
# Sir.          1
# ootherr.      1
# Name: title, dtype: int64

# %%
# Creating a dataframe on the basis of certain titles

temp_df = df[df['title'].isin(['Mr.','Miss.','Mrs.','Master.','ootherr'])]
temp_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 412         1304       NaN       3
# 413         1305       NaN       3
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Now doing a crosstab between survived and title

pd.crosstab(temp_df['Survived'], temp_df['title'], normalize='columns')*100
# Out:
# title     Master.     Miss.        Mr.  Mrs.    ootherr
# Survived
# 0.0          42.5  30.21978  84.332689  20.8  73.684211
# 1.0          57.5  69.78022  15.667311  79.2  26.315789

# %%
# Number of cabin with missing value

df['Cabin'].isnull().sum()/len(df['Cabin'])
# Out:
# 0.774637127578304

# %%
# or

df['Cabin'].isnull().value_counts(normalize=True)
# Out:
# True     0.774637
# False    0.225363
# Name: Cabin, dtype: float64

# %%
# Now replacing all the missing values with "M" i.e. for missing

df['Cabin'].fillna('M', inplace=True)

# %%
# Now checking

df['Cabin'].value_counts()
# Out:
# M                  1014
# C23 C25 C27           6
# B57 B59 B63 B66       5
# G6                    5
# F33                   4
#                    ...
# A14                   1
# E63                   1
# E12                   1
# E38                   1
# C105                  1
# Name: Cabin, Length: 187, dtype: int64

# %%
# Creating a new column named "Deck" on the basis of the initial of Cabin

df['deck'] = df['Cabin'].str[0]
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Now checking the deck values and their frequency

df['deck'].value_counts()
# Out:
# M    1014
# C      94
# B      65
# D      46
# E      41
# A      22
# F      21
# G       5
# T       1
# Name: deck, dtype: int64

# %%
# Doing a crosstab between deck and passenger class

pd.crosstab(df['deck'], df['Pclass'])
# Out:
# Pclass   1    2    3
# deck
# A       22    0    0
# B       65    0    0
# C       94    0    0
# D       40    6    0
# E       34    4    3
# F        0   13    8
# G        0    0    5
# M       67  254  693
# T        1    0    0

# %%
# Checking chances of survival based on deck

pd.crosstab(df['Survived'], df['deck'],  normalize='index')
# Out:
# deck             A         B         C         D         E         F  \
# Survived
# 0.0       0.014572  0.021858  0.043716  0.014572  0.014572  0.009107
# 1.0       0.020468  0.102339  0.102339  0.073099  0.070175  0.023392
#
# deck             G         M         T
# Survived
# 0.0       0.003643  0.876138  0.001821
# 1.0       0.005848  0.602339  0.000000

# %%
# visualizing the result

pd.crosstab(df['deck'], df['Survived'], normalize='index').plot(kind='bar', stacked=True)
plt.show()

# %%
# Checking correlations

df.corr()
# Out:
#                  PassengerId  Survived    Pclass       Age     SibSp  \
# PassengerId         1.000000 -0.005007 -0.038354  0.028814 -0.055224
# Survived           -0.005007  1.000000 -0.338481 -0.077221 -0.035322
# Pclass             -0.038354 -0.338481  1.000000 -0.408106  0.060832
# Age                 0.028814 -0.077221 -0.408106  1.000000 -0.243699
# SibSp              -0.055224 -0.035322  0.060832 -0.243699  1.000000
# Parch               0.008942  0.081629  0.018322 -0.150917  0.373587
# Fare                0.031428  0.257307 -0.558629  0.178740  0.160238
# individual_fare     0.035365  0.221600 -0.504270  0.193545 -0.089807
# family_size        -0.031437  0.016639  0.050027 -0.240229  0.861952
#
#                     Parch      Fare  individual_fare  family_size
# PassengerId      0.008942  0.031428         0.035365    -0.031437
# Survived         0.081629  0.257307         0.221600     0.016639
# Pclass           0.018322 -0.558629        -0.504270     0.050027
# ...

# %%
# Doing a heatmap for correlation between different columns

sns.heatmap(df.corr())
plt.show()

# %%
# Doing a pairplot using seaborn
# Here using df1 as during concatenation the index got repeated

sns.pairplot(df1)
plt.show()
